# %% [markdown]
# ## Convolutional Neural Network
#
# This is implementation of Convolutional Neural Network for the purpose of classification `dog` and `cat`. The dataset contain the test_set and training_set. 1000 images are contained in each dog and cat category of the test_set. 4000 images are contained in each dog and cat category of training_set. We train the model training_set and use test_set as validation data. Then we predict on the custiom images in single_prediction path.

# %% [markdown]
# ### Importing the libaries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# ## Part-1: Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(
                rescale=1./255,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True)

training_set = train_datagen.flow_from_directory(
                'drive/MyDrive/Datasets/cnn-cat-dog/dataset/training_set',
                target_size=(64, 64),
                batch_size=32,
                class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
            'drive/MyDrive/Datasets/cnn-cat-dog/dataset/test_set',
            target_size=(64, 64),
            batch_size=32,
            class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part-2: Building the CNN model

# %% [markdown]
# ### Initialising the CNN

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
model.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Fully Connection

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu'))
model.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part-3: Training the CNN model

# %% [markdown]
# ### Compiling the CNN

# %%
# Check GPU availability
print("GPU", "available (YESSS!!!)" if tf.config.list_physical_devices("GPU") else "not available :(")
# Out:
# GPU available (YESSS!!!)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
model.fit(x = training_set, validation_data = test_set, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 41s 163ms/step - loss: 0.1338 - accuracy: 0.9467 - val_loss: 0.7042 - val_accuracy: 0.7960
# Epoch 2/100
# 250/250 [==============================] - 41s 162ms/step - loss: 0.1267 - accuracy: 0.9521 - val_loss: 0.7268 - val_accuracy: 0.8010
# Epoch 3/100
# 250/250 [==============================] - 40s 161ms/step - loss: 0.1263 - accuracy: 0.9539 - val_loss: 0.7806 - val_accuracy: 0.7830
# Epoch 4/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.1104 - accuracy: 0.9578 - val_loss: 0.8586 - val_accuracy: 0.7825
# Epoch 5/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.1156 - accuracy: 0.9539 - val_loss: 0.8926 - val_accuracy: 0.7790
# Epoch 6/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.1175 - accuracy: 0.9564 - val_loss: 0.7664 - val_accuracy: 0.7930
# Epoch 7/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.1092 - accuracy: 0.9584 - val_loss: 0.7987 - val_accuracy: 0.7980
# Epoch 8/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0960 - accuracy: 0.9634 - val_loss: 0.8693 - val_accuracy: 0.7895
# Epoch 9/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0973 - accuracy: 0.9617 - val_loss: 0.7872 - val_accuracy: 0.8070
# Epoch 10/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0974 - accuracy: 0.9655 - val_loss: 0.9073 - val_accuracy: 0.7970
# Epoch 11/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.1044 - accuracy: 0.9607 - val_loss: 0.8484 - val_accuracy: 0.7955
# Epoch 12/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0954 - accuracy: 0.9644 - val_loss: 0.9180 - val_accuracy: 0.7865
# Epoch 13/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0888 - accuracy: 0.9669 - val_loss: 0.8374 - val_accuracy: 0.8005
# Epoch 14/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0860 - accuracy: 0.9675 - val_loss: 0.8433 - val_accuracy: 0.8010
# Epoch 15/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0874 - accuracy: 0.9665 - val_loss: 0.8880 - val_accuracy: 0.7885
# Epoch 16/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0878 - accuracy: 0.9644 - val_loss: 0.8703 - val_accuracy: 0.7910
# Epoch 17/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0755 - accuracy: 0.9720 - val_loss: 0.9204 - val_accuracy: 0.7960
# Epoch 18/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0854 - accuracy: 0.9680 - val_loss: 0.8983 - val_accuracy: 0.7985
# Epoch 19/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0898 - accuracy: 0.9681 - val_loss: 0.8796 - val_accuracy: 0.7860
# Epoch 20/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0791 - accuracy: 0.9705 - val_loss: 0.8807 - val_accuracy: 0.7945
# Epoch 21/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0757 - accuracy: 0.9710 - val_loss: 0.9471 - val_accuracy: 0.7970
# Epoch 22/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0592 - accuracy: 0.9779 - val_loss: 1.0034 - val_accuracy: 0.7905
# Epoch 23/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.8829 - val_accuracy: 0.8055
# Epoch 24/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0756 - accuracy: 0.9730 - val_loss: 0.8793 - val_accuracy: 0.7895
# Epoch 25/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0672 - accuracy: 0.9744 - val_loss: 0.9048 - val_accuracy: 0.8065
# Epoch 26/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0657 - accuracy: 0.9778 - val_loss: 0.9467 - val_accuracy: 0.7965
# Epoch 27/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0623 - accuracy: 0.9760 - val_loss: 0.9970 - val_accuracy: 0.7905
# Epoch 28/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0805 - accuracy: 0.9714 - val_loss: 0.8986 - val_accuracy: 0.7910
# Epoch 29/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0610 - accuracy: 0.9791 - val_loss: 0.9185 - val_accuracy: 0.7900
# Epoch 30/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0682 - accuracy: 0.9747 - val_loss: 0.9845 - val_accuracy: 0.7945
# Epoch 31/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0590 - accuracy: 0.9780 - val_loss: 1.0045 - val_accuracy: 0.7930
# Epoch 32/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0716 - accuracy: 0.9734 - val_loss: 0.9204 - val_accuracy: 0.7970
# Epoch 33/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0589 - accuracy: 0.9780 - val_loss: 1.1953 - val_accuracy: 0.7650
# Epoch 34/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0594 - accuracy: 0.9786 - val_loss: 1.0557 - val_accuracy: 0.7835
# Epoch 35/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0551 - accuracy: 0.9812 - val_loss: 1.1243 - val_accuracy: 0.7830
# Epoch 36/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0522 - accuracy: 0.9809 - val_loss: 1.0414 - val_accuracy: 0.7975
# Epoch 37/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0555 - accuracy: 0.9790 - val_loss: 1.1816 - val_accuracy: 0.7785
# Epoch 38/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0669 - accuracy: 0.9745 - val_loss: 1.0034 - val_accuracy: 0.7970
# Epoch 39/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0535 - accuracy: 0.9794 - val_loss: 1.0932 - val_accuracy: 0.7855
# Epoch 40/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0499 - accuracy: 0.9841 - val_loss: 1.1003 - val_accuracy: 0.7915
# Epoch 41/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0484 - accuracy: 0.9841 - val_loss: 1.0418 - val_accuracy: 0.8075
# Epoch 42/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0592 - accuracy: 0.9794 - val_loss: 1.0909 - val_accuracy: 0.7840
# Epoch 43/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0531 - accuracy: 0.9806 - val_loss: 0.9817 - val_accuracy: 0.8105
# Epoch 44/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0502 - accuracy: 0.9810 - val_loss: 1.0406 - val_accuracy: 0.7815
# Epoch 45/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0519 - accuracy: 0.9820 - val_loss: 0.9238 - val_accuracy: 0.8080
# Epoch 46/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0536 - accuracy: 0.9812 - val_loss: 1.0893 - val_accuracy: 0.7780
# Epoch 47/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0545 - accuracy: 0.9839 - val_loss: 0.9652 - val_accuracy: 0.7970
# Epoch 48/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0480 - accuracy: 0.9834 - val_loss: 1.0296 - val_accuracy: 0.7980
# Epoch 49/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0539 - accuracy: 0.9796 - val_loss: 1.0748 - val_accuracy: 0.7965
# Epoch 50/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0450 - accuracy: 0.9854 - val_loss: 1.0653 - val_accuracy: 0.7895
# Epoch 51/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0419 - accuracy: 0.9861 - val_loss: 1.0250 - val_accuracy: 0.7970
# Epoch 52/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0539 - accuracy: 0.9835 - val_loss: 0.9235 - val_accuracy: 0.8030
# Epoch 53/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0430 - accuracy: 0.9844 - val_loss: 1.0343 - val_accuracy: 0.7935
# Epoch 54/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0426 - accuracy: 0.9826 - val_loss: 1.2781 - val_accuracy: 0.7735
# Epoch 55/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0552 - accuracy: 0.9803 - val_loss: 1.0683 - val_accuracy: 0.8055
# Epoch 56/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0461 - accuracy: 0.9836 - val_loss: 1.2018 - val_accuracy: 0.7865
# Epoch 57/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0472 - accuracy: 0.9816 - val_loss: 1.1321 - val_accuracy: 0.7915
# Epoch 58/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 1.0349 - val_accuracy: 0.7950
# Epoch 59/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0418 - accuracy: 0.9856 - val_loss: 1.0281 - val_accuracy: 0.7980
# Epoch 60/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0412 - accuracy: 0.9856 - val_loss: 1.0509 - val_accuracy: 0.7960
# Epoch 61/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0397 - accuracy: 0.9858 - val_loss: 1.1000 - val_accuracy: 0.7950
# Epoch 62/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0436 - accuracy: 0.9851 - val_loss: 1.0648 - val_accuracy: 0.7940
# Epoch 63/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0419 - accuracy: 0.9843 - val_loss: 1.0675 - val_accuracy: 0.8020
# Epoch 64/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0435 - accuracy: 0.9840 - val_loss: 1.0858 - val_accuracy: 0.8125
# Epoch 65/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0338 - accuracy: 0.9862 - val_loss: 1.0815 - val_accuracy: 0.8105
# Epoch 66/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0438 - accuracy: 0.9845 - val_loss: 1.0758 - val_accuracy: 0.7945
# Epoch 67/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0379 - accuracy: 0.9866 - val_loss: 1.1974 - val_accuracy: 0.7990
# Epoch 68/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0380 - accuracy: 0.9862 - val_loss: 1.1008 - val_accuracy: 0.7935
# Epoch 69/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0352 - accuracy: 0.9871 - val_loss: 1.1343 - val_accuracy: 0.8060
# Epoch 70/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0343 - accuracy: 0.9887 - val_loss: 1.1376 - val_accuracy: 0.8030
# Epoch 71/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0474 - accuracy: 0.9840 - val_loss: 1.1426 - val_accuracy: 0.7970
# Epoch 72/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0431 - accuracy: 0.9836 - val_loss: 1.0179 - val_accuracy: 0.8085
# Epoch 73/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0388 - accuracy: 0.9860 - val_loss: 1.0843 - val_accuracy: 0.7970
# Epoch 74/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0330 - accuracy: 0.9869 - val_loss: 1.1982 - val_accuracy: 0.8015
# Epoch 75/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0242 - accuracy: 0.9919 - val_loss: 1.2013 - val_accuracy: 0.7960
# Epoch 76/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 1.1492 - val_accuracy: 0.8040
# Epoch 77/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0272 - accuracy: 0.9884 - val_loss: 1.2636 - val_accuracy: 0.7925
# Epoch 78/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0450 - accuracy: 0.9833 - val_loss: 1.1120 - val_accuracy: 0.7900
# Epoch 79/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0400 - accuracy: 0.9859 - val_loss: 1.0684 - val_accuracy: 0.7935
# Epoch 80/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0416 - accuracy: 0.9856 - val_loss: 1.0922 - val_accuracy: 0.8035
# Epoch 81/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0325 - accuracy: 0.9889 - val_loss: 1.1136 - val_accuracy: 0.8090
# Epoch 82/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0351 - accuracy: 0.9881 - val_loss: 1.1405 - val_accuracy: 0.7885
# Epoch 83/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0371 - accuracy: 0.9868 - val_loss: 1.0543 - val_accuracy: 0.7985
# Epoch 84/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0248 - accuracy: 0.9912 - val_loss: 1.2103 - val_accuracy: 0.7985
# Epoch 85/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0353 - accuracy: 0.9871 - val_loss: 1.0995 - val_accuracy: 0.7995
# Epoch 86/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0336 - accuracy: 0.9883 - val_loss: 1.0767 - val_accuracy: 0.7940
# Epoch 87/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0347 - accuracy: 0.9893 - val_loss: 1.0892 - val_accuracy: 0.7950
# Epoch 88/100
# 250/250 [==============================] - 39s 157ms/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 1.3474 - val_accuracy: 0.7975
# Epoch 89/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0353 - accuracy: 0.9877 - val_loss: 1.2133 - val_accuracy: 0.7860
# Epoch 90/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0286 - accuracy: 0.9909 - val_loss: 1.1697 - val_accuracy: 0.7970
# Epoch 91/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0309 - accuracy: 0.9885 - val_loss: 1.2520 - val_accuracy: 0.7990
# Epoch 92/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0308 - accuracy: 0.9891 - val_loss: 1.2563 - val_accuracy: 0.7905
# Epoch 93/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0332 - accuracy: 0.9866 - val_loss: 1.2819 - val_accuracy: 0.7885
# Epoch 94/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0301 - accuracy: 0.9891 - val_loss: 1.2269 - val_accuracy: 0.7940
# Epoch 95/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 1.1993 - val_accuracy: 0.7890
# Epoch 96/100
# 250/250 [==============================] - 40s 158ms/step - loss: 0.0375 - accuracy: 0.9864 - val_loss: 1.1779 - val_accuracy: 0.8025
# Epoch 97/100
# 250/250 [==============================] - 40s 160ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 1.1337 - val_accuracy: 0.8030
# Epoch 98/100
# 250/250 [==============================] - 44s 175ms/step - loss: 0.0226 - accuracy: 0.9923 - val_loss: 1.3305 - val_accuracy: 0.7870
# Epoch 99/100
# 250/250 [==============================] - 40s 159ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 1.3575 - val_accuracy: 0.7905
# Epoch 100/100
# 250/250 [==============================] - 39s 158ms/step - loss: 0.0326 - accuracy: 0.9884 - val_loss: 1.1991 - val_accuracy: 0.7870

# %% [markdown]
# ## Part-4: Making prediction

# %% [markdown]
# Let's make prediction on the images inside `drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/` path.

# %%
import os
custom_path = "drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/"
custom_image_paths = [custom_path + fname for fname in os.listdir(custom_path)]

# %%
custom_image_paths
# Out:
# ['drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/dog.4012.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/dog.4002.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/dog.4039.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/dog.4184.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat.4003.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat.4079.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat.4159.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat.4146.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat_or_dog_1.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat_or_dog_2.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat_or_dog_3.jpg',
#  'drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/cat_or_dog_4.jpg']

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
custom_path = "drive/MyDrive/Datasets/cnn-cat-dog/dataset/single_prediction/"
custom_image_paths = [custom_path + fname for fname in os.listdir(custom_path)]
size = np.ceil(np.sqrt(len(custom_image_paths)))

plt.figure(figsize=(15, 15))
for i, image_path in enumerate(custom_image_paths):
  from keras.preprocessing import image
  test_image = image.load_img(image_path, target_size=(64, 64))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result = model.predict(test_image)
  training_set.class_indices    # This check and print class indices like this {'cats': 0, 'dogs': 1}
  if result[0][0] == 1:
    prediction = 'dog'
  else:
    prediction = 'cat'

  plt.subplot(size, size, i+1)
  plt.xticks([]), plt.yticks([])
  plt.title(prediction)
  image = plt.imread(image_path)
  plt.imshow(image)
